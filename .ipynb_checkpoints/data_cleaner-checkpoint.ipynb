# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as cns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier

from joblib import dump

# %%
df = pd.read_csv("./cars_data_copy.csv")
df
# Out:
#                model  year    price transmission  mileage fuelType  tax   mpg  \
# 0                I10  2017   7495.0       Manual    11630   Petrol  145  60.1
# 1               Polo  2017  10989.0       Manual     9200   Petrol  145  58.9
# 2           2 Series  2019  27990.0    Semi-Auto     1614   Diesel  145  49.6
# 3       Yeti Outdoor  2017  12495.0       Manual    30960   Diesel  150  62.8
# 4             Fiesta  2017   7999.0       Manual    19353   Petrol  125  54.3
# ...              ...   ...      ...          ...      ...      ...  ...   ...
# 97707         Fiesta  2017  10447.0    Automatic     8337   Petrol  145  54.3
# 97708       3 Series  2014  14995.0       Manual    25372   Diesel   30  61.4
# 97709         Fiesta  2017   8950.0       Manual    19910   Petrol  125  54.3
# 97710          Astra  2017  10700.0    Automatic    24468   Petrol  125  50.4
# 97711    Grandland X  2019  15798.0       Manual    10586   Diesel  150  48.7
#
#        engineSize Manufacturer
# ...

# %%
def getAge(x):
    return 2026 - x
getAge(2017)
# Out:
# 9

# %%
df2 = df.copy()
df2
# Out:
#                model  year    price transmission  mileage fuelType  tax   mpg  \
# 0                I10  2017   7495.0       Manual    11630   Petrol  145  60.1
# 1               Polo  2017  10989.0       Manual     9200   Petrol  145  58.9
# 2           2 Series  2019  27990.0    Semi-Auto     1614   Diesel  145  49.6
# 3       Yeti Outdoor  2017  12495.0       Manual    30960   Diesel  150  62.8
# 4             Fiesta  2017   7999.0       Manual    19353   Petrol  125  54.3
# ...              ...   ...      ...          ...      ...      ...  ...   ...
# 97707         Fiesta  2017  10447.0    Automatic     8337   Petrol  145  54.3
# 97708       3 Series  2014  14995.0       Manual    25372   Diesel   30  61.4
# 97709         Fiesta  2017   8950.0       Manual    19910   Petrol  125  54.3
# 97710          Astra  2017  10700.0    Automatic    24468   Petrol  125  50.4
# 97711    Grandland X  2019  15798.0       Manual    10586   Diesel  150  48.7
#
#        engineSize Manufacturer
# ...

# %%
# Eliminar los NaN de price, mileage y tax, por los promedios primero
imp = SimpleImputer(missing_values = np.nan, strategy = "mean")

# %%
df2[["price","mileage","tax"]] = imp.fit_transform(df2[["price","mileage","tax"]])
df2
# Out:
#                model  year    price transmission  mileage fuelType    tax  \
# 0                I10  2017   7495.0       Manual  11630.0   Petrol  145.0
# 1               Polo  2017  10989.0       Manual   9200.0   Petrol  145.0
# 2           2 Series  2019  27990.0    Semi-Auto   1614.0   Diesel  145.0
# 3       Yeti Outdoor  2017  12495.0       Manual  30960.0   Diesel  150.0
# 4             Fiesta  2017   7999.0       Manual  19353.0   Petrol  125.0
# ...              ...   ...      ...          ...      ...      ...    ...
# 97707         Fiesta  2017  10447.0    Automatic   8337.0   Petrol  145.0
# 97708       3 Series  2014  14995.0       Manual  25372.0   Diesel   30.0
# 97709         Fiesta  2017   8950.0       Manual  19910.0   Petrol  125.0
# 97710          Astra  2017  10700.0    Automatic  24468.0   Petrol  125.0
# 97711    Grandland X  2019  15798.0       Manual  10586.0   Diesel  150.0
#
#         mpg  engineSize Manufacturer
# 0      60.1         1.0       hyundi
# ...

# %%
df2.isnull().sum()
# Out:
# model              0
# year               0
# price              0
# transmission       0
# mileage            0
# fuelType        4126
# tax                0
# mpg             3456
# engineSize         0
# Manufacturer       0
# dtype: int64

# %%
df2["age"] = df2["year"].apply(getAge)
df2
# Out:
#                model  year    price transmission  mileage fuelType    tax  \
# 0                I10  2017   7495.0       Manual  11630.0   Petrol  145.0
# 1               Polo  2017  10989.0       Manual   9200.0   Petrol  145.0
# 2           2 Series  2019  27990.0    Semi-Auto   1614.0   Diesel  145.0
# 3       Yeti Outdoor  2017  12495.0       Manual  30960.0   Diesel  150.0
# 4             Fiesta  2017   7999.0       Manual  19353.0   Petrol  125.0
# ...              ...   ...      ...          ...      ...      ...    ...
# 97707         Fiesta  2017  10447.0    Automatic   8337.0   Petrol  145.0
# 97708       3 Series  2014  14995.0       Manual  25372.0   Diesel   30.0
# 97709         Fiesta  2017   8950.0       Manual  19910.0   Petrol  125.0
# 97710          Astra  2017  10700.0    Automatic  24468.0   Petrol  125.0
# 97711    Grandland X  2019  15798.0       Manual  10586.0   Diesel  150.0
#
#         mpg  engineSize Manufacturer  age
# ...

# %%
df2.isnull().sum()
# Out:
# model              0
# year               0
# price              0
# transmission       0
# mileage            0
# fuelType        4126
# tax                0
# mpg             3456
# engineSize         0
# Manufacturer       0
# age                0
# dtype: int64

# %%
df2 = df2.drop(columns = ["model", "year"])
df2
# Out:
#          price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0       7495.0       Manual  11630.0   Petrol  145.0  60.1         1.0
# 1      10989.0       Manual   9200.0   Petrol  145.0  58.9         1.0
# 2      27990.0    Semi-Auto   1614.0   Diesel  145.0  49.6         2.0
# 3      12495.0       Manual  30960.0   Diesel  150.0  62.8         2.0
# 4       7999.0       Manual  19353.0   Petrol  125.0  54.3         1.2
# ...        ...          ...      ...      ...    ...   ...         ...
# 97707  10447.0    Automatic   8337.0   Petrol  145.0  54.3         1.0
# 97708  14995.0       Manual  25372.0   Diesel   30.0  61.4         2.0
# 97709   8950.0       Manual  19910.0   Petrol  125.0  54.3         1.2
# 97710  10700.0    Automatic  24468.0   Petrol  125.0  50.4         1.4
# 97711  15798.0       Manual  10586.0   Diesel  150.0  48.7         1.5
#
#       Manufacturer  age
# 0           hyundi    9
# 1       volkswagen    9
# 2              BMW    7
# ...

# %%
df2.isnull().sum()
# Out:
# price              0
# transmission       0
# mileage            0
# fuelType        4126
# tax                0
# mpg             3456
# engineSize         0
# Manufacturer       0
# age                0
# dtype: int64

# %%
imp = SimpleImputer(missing_values = np.nan, strategy = "most_frequent")

# %%
df2[["fuelType","mpg"]] = imp.fit_transform(df2[["fuelType","mpg"]])
df2
# Out:
#          price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0       7495.0       Manual  11630.0   Petrol  145.0  60.1         1.0
# 1      10989.0       Manual   9200.0   Petrol  145.0  58.9         1.0
# 2      27990.0    Semi-Auto   1614.0   Diesel  145.0  49.6         2.0
# 3      12495.0       Manual  30960.0   Diesel  150.0  62.8         2.0
# 4       7999.0       Manual  19353.0   Petrol  125.0  54.3         1.2
# ...        ...          ...      ...      ...    ...   ...         ...
# 97707  10447.0    Automatic   8337.0   Petrol  145.0  54.3         1.0
# 97708  14995.0       Manual  25372.0   Diesel   30.0  61.4         2.0
# 97709   8950.0       Manual  19910.0   Petrol  125.0  54.3         1.2
# 97710  10700.0    Automatic  24468.0   Petrol  125.0  50.4         1.4
# 97711  15798.0       Manual  10586.0   Diesel  150.0  48.7         1.5
#
#       Manufacturer  age
# 0           hyundi    9
# 1       volkswagen    9
# 2              BMW    7
# ...

# %%
df2.isnull().sum()
# Out:
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Manufacturer    0
# age             0
# dtype: int64

# %%
df2
# Out:
#          price transmission  mileage fuelType    tax   mpg  engineSize  \
# 0       7495.0       Manual  11630.0   Petrol  145.0  60.1         1.0
# 1      10989.0       Manual   9200.0   Petrol  145.0  58.9         1.0
# 2      27990.0    Semi-Auto   1614.0   Diesel  145.0  49.6         2.0
# 3      12495.0       Manual  30960.0   Diesel  150.0  62.8         2.0
# 4       7999.0       Manual  19353.0   Petrol  125.0  54.3         1.2
# ...        ...          ...      ...      ...    ...   ...         ...
# 97707  10447.0    Automatic   8337.0   Petrol  145.0  54.3         1.0
# 97708  14995.0       Manual  25372.0   Diesel   30.0  61.4         2.0
# 97709   8950.0       Manual  19910.0   Petrol  125.0  54.3         1.2
# 97710  10700.0    Automatic  24468.0   Petrol  125.0  50.4         1.4
# 97711  15798.0       Manual  10586.0   Diesel  150.0  48.7         1.5
#
#       Manufacturer  age
# 0           hyundi    9
# 1       volkswagen    9
# 2              BMW    7
# ...

# %%
# Ahora clasificamos las cosas que pueden ser solamente de ciertos tipos
# Ejemplo: transmission, fuelType, Manufacturer
le = LabelEncoder()

# %%
df2["transmission"] = le.fit_transform(df2["transmission"])
df2
# Out:
#          price  transmission  mileage fuelType    tax   mpg  engineSize  \
# 0       7495.0             1  11630.0   Petrol  145.0  60.1         1.0
# 1      10989.0             1   9200.0   Petrol  145.0  58.9         1.0
# 2      27990.0             3   1614.0   Diesel  145.0  49.6         2.0
# 3      12495.0             1  30960.0   Diesel  150.0  62.8         2.0
# 4       7999.0             1  19353.0   Petrol  125.0  54.3         1.2
# ...        ...           ...      ...      ...    ...   ...         ...
# 97707  10447.0             0   8337.0   Petrol  145.0  54.3         1.0
# 97708  14995.0             1  25372.0   Diesel   30.0  61.4         2.0
# 97709   8950.0             1  19910.0   Petrol  125.0  54.3         1.2
# 97710  10700.0             0  24468.0   Petrol  125.0  50.4         1.4
# 97711  15798.0             1  10586.0   Diesel  150.0  48.7         1.5
#
#       Manufacturer  age
# 0           hyundi    9
# 1       volkswagen    9
# 2              BMW    7
# ...

# %%
df2.isnull().sum()
# Out:
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Manufacturer    0
# age             0
# dtype: int64

# %%
df2["fuelType"] = le.fit_transform(df2["fuelType"])
df2
# Out:
#          price  transmission  mileage  fuelType    tax   mpg  engineSize  \
# 0       7495.0             1  11630.0         4  145.0  60.1         1.0
# 1      10989.0             1   9200.0         4  145.0  58.9         1.0
# 2      27990.0             3   1614.0         0  145.0  49.6         2.0
# 3      12495.0             1  30960.0         0  150.0  62.8         2.0
# 4       7999.0             1  19353.0         4  125.0  54.3         1.2
# ...        ...           ...      ...       ...    ...   ...         ...
# 97707  10447.0             0   8337.0         4  145.0  54.3         1.0
# 97708  14995.0             1  25372.0         0   30.0  61.4         2.0
# 97709   8950.0             1  19910.0         4  125.0  54.3         1.2
# 97710  10700.0             0  24468.0         4  125.0  50.4         1.4
# 97711  15798.0             1  10586.0         0  150.0  48.7         1.5
#
#       Manufacturer  age
# 0           hyundi    9
# 1       volkswagen    9
# ...

# %%
# Funcion para generar aleatoriamente un (0 | 1)
def genRecommended(row):
    score = 0

    if row["age"] <= 5:
        score += 1

    if row["mileage"] < 25000:
        score += 1

    if row["engineSize"] <= 2.0:
        score += 1

    return 1 if score >= 2 else 0

# %%
df2["recommended"] = df2.apply(genRecommended, axis = 1)
df2[df2["recommended"] == 1]
# Out:
#          price  transmission  mileage  fuelType    tax   mpg  engineSize  \
# 0       7495.0             1  11630.0         4  145.0  60.1         1.0
# 1      10989.0             1   9200.0         4  145.0  58.9         1.0
# 2      27990.0             3   1614.0         0  145.0  49.6         2.0
# 4       7999.0             1  19353.0         4  125.0  54.3         1.2
# 5      26791.0             0   2373.0         2  135.0  74.3         1.8
# ...        ...           ...      ...       ...    ...   ...         ...
# 97704  11995.0             1  15900.0         4  145.0  57.7         1.0
# 97707  10447.0             0   8337.0         4  145.0  54.3         1.0
# 97709   8950.0             1  19910.0         4  125.0  54.3         1.2
# 97710  10700.0             0  24468.0         4  125.0  50.4         1.4
# 97711  15798.0             1  10586.0         0  150.0  48.7         1.5
#
#       Manufacturer  age  recommended
# 0           hyundi    9            1
# ...

# %%
df2.isnull().sum()
# Out:
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Manufacturer    0
# age             0
# recommended     0
# dtype: int64

# %%
df2["Manufacturer"] = le.fit_transform(df2["Manufacturer"])
df2
# Out:
#          price  transmission  mileage  fuelType    tax   mpg  engineSize  \
# 0       7495.0             1  11630.0         4  145.0  60.1         1.0
# 1      10989.0             1   9200.0         4  145.0  58.9         1.0
# 2      27990.0             3   1614.0         0  145.0  49.6         2.0
# 3      12495.0             1  30960.0         0  150.0  62.8         2.0
# 4       7999.0             1  19353.0         4  125.0  54.3         1.2
# ...        ...           ...      ...       ...    ...   ...         ...
# 97707  10447.0             0   8337.0         4  145.0  54.3         1.0
# 97708  14995.0             1  25372.0         0   30.0  61.4         2.0
# 97709   8950.0             1  19910.0         4  125.0  54.3         1.2
# 97710  10700.0             0  24468.0         4  125.0  50.4         1.4
# 97711  15798.0             1  10586.0         0  150.0  48.7         1.5
#
#        Manufacturer  age  recommended
# 0                 3    9            1
# ...

# %%
df2.isnull().sum()
# Out:
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Manufacturer    0
# age             0
# recommended     0
# dtype: int64

# %%
df2[["price", "mpg"]].describe()
# Out:
#                price
# count   97712.000000
# mean    16774.299823
# std      9824.816719
# min       450.000000
# 25%     10000.000000
# 50%     14498.000000
# 75%     20590.000000
# max    159999.000000

# %%
df2[["price", "mpg"]].isna().sum()
# Out:
# price    0
# mpg      0
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2[["price", "mpg"]].isna().sum()
# Out:
# price    0
# mpg      0
# dtype: int64

# %%
# Ahora escalamos los datos que necesitan ser escalados
sc = StandardScaler()

# %%
df2[["price","mileage","tax","mpg"]] = sc.fit_transform(df2[["price","mileage","tax","mpg"]])
df2
# Out:
#           price  transmission   mileage  fuelType       tax       mpg  \
# 0     -0.944480             1 -0.550287         4  0.392342  0.293146
# 1     -0.588849             1 -0.665668         4  0.392342  0.218290
# 2      1.141574             3 -1.025863         0  0.392342 -0.361843
# 3     -0.435562             1  0.367533         0  0.471260  0.461572
# 4     -0.893182             1 -0.183587         4  0.076670 -0.068657
# ...         ...           ...       ...       ...       ...       ...
# 97707 -0.644015             0 -0.706644         4  0.392342 -0.068657
# 97708 -0.181104             1  0.102205         0 -1.422771  0.374240
# 97709 -0.796385             1 -0.157139         4  0.076670 -0.068657
# 97710 -0.618264             0  0.059282         4  0.076670 -0.311939
# 97711 -0.099371             1 -0.599858         0  0.471260 -0.417985
#
#        engineSize  Manufacturer  age  recommended
# 0             1.0             3    9            1
# ...

# %%
df2.isnull().sum()
# Out:
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Manufacturer    0
# age             0
# recommended     0
# dtype: int64

# %%
df2.corr()
# Out:
#                  price  transmission   mileage  fuelType       tax       mpg  \
# price         1.000000      0.239405 -0.415618 -0.218893  0.305616 -0.289724
# transmission  0.239405      1.000000 -0.125684 -0.059044  0.073363 -0.106105
# mileage      -0.415618     -0.125684  1.000000 -0.220462 -0.215558  0.179016
# fuelType     -0.218893     -0.059044 -0.220462  1.000000  0.096464 -0.215004
# tax           0.305616      0.073363 -0.215558  0.096464  1.000000 -0.440598
# mpg          -0.289724     -0.106105  0.179016 -0.215004 -0.440598  1.000000
# engineSize    0.636711      0.149934  0.107299 -0.491055  0.280770 -0.244700
# Manufacturer -0.223497     -0.071924 -0.036642  0.146142 -0.050463 -0.014983
# age          -0.489649     -0.143108  0.739664 -0.070635 -0.192058  0.128283
# recommended   0.072830      0.032493 -0.679680  0.277737  0.180420 -0.087806
#
#               engineSize  Manufacturer       age  recommended
# ...

# %%
plt.figure(figsize = (20, 10))
cns.heatmap(df2.corr(), cmap = "coolwarm", annot = True)
plt.show()

# %%
df2.isnull().sum()
# Out:
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Manufacturer    0
# age             0
# recommended     0
# dtype: int64

# %%
x = df2.drop("recommended", axis = 1)
x.head()
# Out:
#       price  transmission   mileage  fuelType       tax       mpg  engineSize  \
# 0 -0.944480             1 -0.550287         4  0.392342  0.293146         1.0
# 1 -0.588849             1 -0.665668         4  0.392342  0.218290         1.0
# 2  1.141574             3 -1.025863         0  0.392342 -0.361843         2.0
# 3 -0.435562             1  0.367533         0  0.471260  0.461572         2.0
# 4 -0.893182             1 -0.183587         4  0.076670 -0.068657         1.2
#
#    Manufacturer  age
# 0             3    9
# 1             8    9
# 2             1    7
# 3             5    9
# 4             2    9

# %%
y = df2["recommended"]
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 97707    1
# 97708    0
# 97709    1
# 97710    1
# 97711    1
# Name: recommended, Length: 97712, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, shuffle = True, random_state = 42)
x_train.shape
# Out:
# (78169, 9)

# %%
y_train.shape
# Out:
# (78169,)

# %%
x_test.shape
# Out:
# (19543, 9)

# %%
y_test.shape
# Out:
# (19543,)

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)
y_pred[0:10]
# Out:
# array([1, 1, 0, 1, 0, 1, 0, 0, 0, 0])

# %%
y_test.head(10)
# Out:
# 94478    1
# 47748    1
# 35052    1
# 49337    1
# 40454    0
# 30848    1
# 62562    0
# 37266    0
# 40394    0
# 79850    1
# Name: recommended, dtype: int64

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.9320472803561377

# %%
model = RandomForestClassifier(n_estimators=100)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 1.0

# %%
dump(model, "model.pkl", compress=3)
# Out:
# ['model.pkl']

# %%
model = GradientBoostingClassifier(n_estimators=100)

# %%
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
acc = accuracy_score(y_test, y_pred)

# %%
acc
# Out:
# 1.0

# %%
model = SVC(kernel='linear')

# %%
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
acc = accuracy_score(y_test, y_pred)

# %%
acc
# Out:
# 0.9325078033055314

# %%
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
acc = accuracy_score(y_test, y_pred)

# %%
acc
# Out:
# 1.0

# %%
model = MLPClassifier(hidden_layer_sizes=(100,50))

# %%
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
acc = accuracy_score(y_test, y_pred)

# %%
acc
# Out:
# 0.996008801105255
